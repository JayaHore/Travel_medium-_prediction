# %% [markdown]
# <a href="https://colab.research.google.com/github/JayaHore/Travel_medium-_prediction/blob/main/travel_medium_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import csv

def json_to_csv(json_file_path, csv_file_path):
    """
    Convert JSON sensor data to CSV format with error handling.

    Args:
        json_file_path: Path to input JSON file
        csv_file_path: Path to output CSV file
    """
    # Define CSV columns
    columns = ['time', 'acc_x', 'acc_y', 'acc_z', 'gyro_x', 'gyro_y', 'gyro_z', 'label']

    try:
        # Read the JSON file
        with open(json_file_path, 'r') as f:
            content = f.read()

        # Try to parse the JSON
        try:
            data = json.loads(content)
        except json.JSONDecodeError as e:
            print(f"JSON parsing error: {e}")
            print("Attempting to fix the JSON file...")

            # Try to fix common issues
            # 1. Add closing bracket if missing
            if not content.rstrip().endswith(']'):
                content = content.rstrip().rstrip(',') + ']'
                data = json.loads(content)
            else:
                raise

        # Ensure data is a list
        if not isinstance(data, list):
            print("Error: JSON root should be an array")
            return

        # Write to CSV
        with open(csv_file_path, 'w', newline='') as f:
            writer = csv.DictWriter(f, fieldnames=columns)
            writer.writeheader()

            # Write each record
            valid_records = 0
            for i, record in enumerate(data):
                try:
                    writer.writerow({
                        'time': record.get('time', ''),
                        'acc_x': record.get('acc_x', ''),
                        'acc_y': record.get('acc_y', ''),
                        'acc_z': record.get('acc_z', ''),
                        'gyro_x': record.get('gyro_x', ''),
                        'gyro_y': record.get('gyro_y', ''),
                        'gyro_z': record.get('gyro_z', ''),
                        'label': record.get('label', '')
                    })
                    valid_records += 1
                except Exception as e:
                    print(f"Error writing record {i}: {e}")

        print(f"✓ CSV file created successfully: {csv_file_path}")
        print(f"✓ Total records written: {valid_records}")

    except FileNotFoundError:
        print(f"Error: File '{json_file_path}' not found")
    except Exception as e:
        print(f"Error: {e}")

# Usage
if __name__ == "__main__":
    input_file = "/content/merged_auto.json"  # Your JSON file path in Colab
    output_file = "/content/sensor_auto_data.csv"   # Output CSV file

    json_to_csv(input_file, output_file)
# Out:
# ✓ CSV file created successfully: /content/sensor_auto_data.csv
# ✓ Total records written: 214357

# %%
import json
import csv

def json_to_csv(json_file_path, csv_file_path):
    """
    Convert JSON sensor data to CSV format with error handling.

    Args:
        json_file_path: Path to input JSON file
        csv_file_path: Path to output CSV file
    """
    # Define CSV columns
    columns = ['time', 'acc_x', 'acc_y', 'acc_z', 'gyro_x', 'gyro_y', 'gyro_z', 'label']

    try:
        # Read the JSON file
        with open(json_file_path, 'r') as f:
            content = f.read()

        # Try to parse the JSON
        try:
            data = json.loads(content)
        except json.JSONDecodeError as e:
            print(f"JSON parsing error: {e}")
            print("Attempting to fix the JSON file...")

            # Try to fix common issues
            # 1. Add closing bracket if missing
            if not content.rstrip().endswith(']'):
                content = content.rstrip().rstrip(',') + ']'
                data = json.loads(content)
            else:
                raise

        # Ensure data is a list
        if not isinstance(data, list):
            print("Error: JSON root should be an array")
            return

        # Write to CSV
        with open(csv_file_path, 'w', newline='') as f:
            writer = csv.DictWriter(f, fieldnames=columns)
            writer.writeheader()

            # Write each record
            valid_records = 0
            for i, record in enumerate(data):
                try:
                    writer.writerow({
                        'time': record.get('time', ''),
                        'acc_x': record.get('acc_x', ''),
                        'acc_y': record.get('acc_y', ''),
                        'acc_z': record.get('acc_z', ''),
                        'gyro_x': record.get('gyro_x', ''),
                        'gyro_y': record.get('gyro_y', ''),
                        'gyro_z': record.get('gyro_z', ''),
                        'label': record.get('label', '')
                    })
                    valid_records += 1
                except Exception as e:
                    print(f"Error writing record {i}: {e}")

        print(f"✓ CSV file created successfully: {csv_file_path}")
        print(f"✓ Total records written: {valid_records}")

    except FileNotFoundError:
        print(f"Error: File '{json_file_path}' not found")
    except Exception as e:
        print(f"Error: {e}")

# Usage
if __name__ == "__main__":
    input_file = "/content/merged_bike.json"  # Your JSON file path in Colab
    output_file = "/content/sensor_bike_data.csv"   # Output CSV file

    json_to_csv(input_file, output_file)
# Out:
# ✓ CSV file created successfully: /content/sensor_bike_data.csv
# ✓ Total records written: 53360

# %%
import json
import csv

def json_to_csv(json_file_path, csv_file_path):
    """
    Convert JSON sensor data to CSV format with error handling.

    Args:
        json_file_path: Path to input JSON file
        csv_file_path: Path to output CSV file
    """
    # Define CSV columns
    columns = ['time', 'acc_x', 'acc_y', 'acc_z', 'gyro_x', 'gyro_y', 'gyro_z', 'label']

    try:
        # Read the JSON file
        with open(json_file_path, 'r') as f:
            content = f.read()

        # Try to parse the JSON
        try:
            data = json.loads(content)
        except json.JSONDecodeError as e:
            print(f"JSON parsing error: {e}")
            print("Attempting to fix the JSON file...")

            # Try to fix common issues
            # 1. Add closing bracket if missing
            if not content.rstrip().endswith(']'):
                content = content.rstrip().rstrip(',') + ']'
                data = json.loads(content)
            else:
                raise

        # Ensure data is a list
        if not isinstance(data, list):
            print("Error: JSON root should be an array")
            return

        # Write to CSV
        with open(csv_file_path, 'w', newline='') as f:
            writer = csv.DictWriter(f, fieldnames=columns)
            writer.writeheader()

            # Write each record
            valid_records = 0
            for i, record in enumerate(data):
                try:
                    writer.writerow({
                        'time': record.get('time', ''),
                        'acc_x': record.get('acc_x', ''),
                        'acc_y': record.get('acc_y', ''),
                        'acc_z': record.get('acc_z', ''),
                        'gyro_x': record.get('gyro_x', ''),
                        'gyro_y': record.get('gyro_y', ''),
                        'gyro_z': record.get('gyro_z', ''),
                        'label': record.get('label', '')
                    })
                    valid_records += 1
                except Exception as e:
                    print(f"Error writing record {i}: {e}")

        print(f"✓ CSV file created successfully: {csv_file_path}")
        print(f"✓ Total records written: {valid_records}")

    except FileNotFoundError:
        print(f"Error: File '{json_file_path}' not found")
    except Exception as e:
        print(f"Error: {e}")

# Usage
if __name__ == "__main__":
    input_file = "/content/merged_bus.json"  # Your JSON file path in Colab
    output_file = "/content/sensor_bus_data.csv"   # Output CSV file

    json_to_csv(input_file, output_file)
# Out:
# ✓ CSV file created successfully: /content/sensor_bus_data.csv
# ✓ Total records written: 465265

# %%
import json
import csv

def json_to_csv(json_file_path, csv_file_path):
    """
    Convert JSON sensor data to CSV format with error handling.

    Args:
        json_file_path: Path to input JSON file
        csv_file_path: Path to output CSV file
    """
    # Define CSV columns
    columns = ['time', 'acc_x', 'acc_y', 'acc_z', 'gyro_x', 'gyro_y', 'gyro_z', 'label']

    try:
        # Read the JSON file
        with open(json_file_path, 'r') as f:
            content = f.read()

        # Try to parse the JSON
        try:
            data = json.loads(content)
        except json.JSONDecodeError as e:
            print(f"JSON parsing error: {e}")
            print("Attempting to fix the JSON file...")

            # Try to fix common issues
            # 1. Add closing bracket if missing
            if not content.rstrip().endswith(']'):
                content = content.rstrip().rstrip(',') + ']'
                data = json.loads(content)
            else:
                raise

        # Ensure data is a list
        if not isinstance(data, list):
            print("Error: JSON root should be an array")
            return

        # Write to CSV
        with open(csv_file_path, 'w', newline='') as f:
            writer = csv.DictWriter(f, fieldnames=columns)
            writer.writeheader()

            # Write each record
            valid_records = 0
            for i, record in enumerate(data):
                try:
                    writer.writerow({
                        'time': record.get('time', ''),
                        'acc_x': record.get('acc_x', ''),
                        'acc_y': record.get('acc_y', ''),
                        'acc_z': record.get('acc_z', ''),
                        'gyro_x': record.get('gyro_x', ''),
                        'gyro_y': record.get('gyro_y', ''),
                        'gyro_z': record.get('gyro_z', ''),
                        'label': record.get('label', '')
                    })
                    valid_records += 1
                except Exception as e:
                    print(f"Error writing record {i}: {e}")

        print(f"✓ CSV file created successfully: {csv_file_path}")
        print(f"✓ Total records written: {valid_records}")

    except FileNotFoundError:
        print(f"Error: File '{json_file_path}' not found")
    except Exception as e:
        print(f"Error: {e}")

# Usage
if __name__ == "__main__":
    input_file = "/content/merged_cycle.json"  # Your JSON file path in Colab
    output_file = "/content/sensor_cycle_data.csv"   # Output CSV file

    json_to_csv(input_file, output_file)
# Out:
# ✓ CSV file created successfully: /content/sensor_cycle_data.csv
# ✓ Total records written: 105007

# %%
import json
import csv

def json_to_csv(json_file_path, csv_file_path):
    """
    Convert JSON sensor data to CSV format with error handling.

    Args:
        json_file_path: Path to input JSON file
        csv_file_path: Path to output CSV file
    """
    # Define CSV columns
    columns = ['time', 'acc_x', 'acc_y', 'acc_z', 'gyro_x', 'gyro_y', 'gyro_z', 'label']

    try:
        # Read the JSON file
        with open(json_file_path, 'r') as f:
            content = f.read()

        # Try to parse the JSON
        try:
            data = json.loads(content)
        except json.JSONDecodeError as e:
            print(f"JSON parsing error: {e}")
            print("Attempting to fix the JSON file...")

            # Try to fix common issues
            # 1. Add closing bracket if missing
            if not content.rstrip().endswith(']'):
                content = content.rstrip().rstrip(',') + ']'
                data = json.loads(content)
            else:
                raise

        # Ensure data is a list
        if not isinstance(data, list):
            print("Error: JSON root should be an array")
            return

        # Write to CSV
        with open(csv_file_path, 'w', newline='') as f:
            writer = csv.DictWriter(f, fieldnames=columns)
            writer.writeheader()

            # Write each record
            valid_records = 0
            for i, record in enumerate(data):
                try:
                    writer.writerow({
                        'time': record.get('time', ''),
                        'acc_x': record.get('acc_x', ''),
                        'acc_y': record.get('acc_y', ''),
                        'acc_z': record.get('acc_z', ''),
                        'gyro_x': record.get('gyro_x', ''),
                        'gyro_y': record.get('gyro_y', ''),
                        'gyro_z': record.get('gyro_z', ''),
                        'label': record.get('label', '')
                    })
                    valid_records += 1
                except Exception as e:
                    print(f"Error writing record {i}: {e}")

        print(f"✓ CSV file created successfully: {csv_file_path}")
        print(f"✓ Total records written: {valid_records}")

    except FileNotFoundError:
        print(f"Error: File '{json_file_path}' not found")
    except Exception as e:
        print(f"Error: {e}")

# Usage
if __name__ == "__main__":
    input_file = "/content/merged_toto_new.json"  # Your JSON file path in Colab
    output_file = "/content/sensor_toto_new_data.csv"   # Output CSV file

    json_to_csv(input_file, output_file)
# Out:
# JSON parsing error: Expecting ':' delimiter: line 34637147 column 22 (char 923224691)
# Attempting to fix the JSON file...
# Error: Expecting ':' delimiter: line 34637147 column 22 (char 923224691)

# %%
import json
import csv

def json_to_csv(json_file_path, csv_file_path):
    """
    Convert JSON sensor data to CSV format with error handling.

    Args:
        json_file_path: Path to input JSON file
        csv_file_path: Path to output CSV file
    """
    # Define CSV columns
    columns = ['time', 'acc_x', 'acc_y', 'acc_z', 'gyro_x', 'gyro_y', 'gyro_z', 'label']

    try:
        # Read the JSON file
        with open(json_file_path, 'r') as f:
            content = f.read()

        # Try to parse the JSON
        try:
            data = json.loads(content)
        except json.JSONDecodeError as e:
            print(f"JSON parsing error: {e}")
            print("Attempting to fix the JSON file...")

            # Try to fix common issues
            # 1. Add closing bracket if missing
            if not content.rstrip().endswith(']'):
                content = content.rstrip().rstrip(',') + ']'
                data = json.loads(content)
            else:
                raise

        # Ensure data is a list
        if not isinstance(data, list):
            print("Error: JSON root should be an array")
            return

        # Write to CSV
        with open(csv_file_path, 'w', newline='') as f:
            writer = csv.DictWriter(f, fieldnames=columns)
            writer.writeheader()

            # Write each record
            valid_records = 0
            for i, record in enumerate(data):
                try:
                    writer.writerow({
                        'time': record.get('time', ''),
                        'acc_x': record.get('acc_x', ''),
                        'acc_y': record.get('acc_y', ''),
                        'acc_z': record.get('acc_z', ''),
                        'gyro_x': record.get('gyro_x', ''),
                        'gyro_y': record.get('gyro_y', ''),
                        'gyro_z': record.get('gyro_z', ''),
                        'label': record.get('label', '')
                    })
                    valid_records += 1
                except Exception as e:
                    print(f"Error writing record {i}: {e}")

        print(f"✓ CSV file created successfully: {csv_file_path}")
        print(f"✓ Total records written: {valid_records}")

    except FileNotFoundError:
        print(f"Error: File '{json_file_path}' not found")
    except Exception as e:
        print(f"Error: {e}")

# Usage
if __name__ == "__main__":
    input_file = "/content/merged_train.json"  # Your JSON file path in Colab
    output_file = "/content/sensor_train_data.csv"   # Output CSV file

    json_to_csv(input_file, output_file)
# Out:
# ✓ CSV file created successfully: /content/sensor_train_data.csv
# ✓ Total records written: 2964963

# %%
import json
import csv

def json_to_csv(json_file_path, csv_file_path):
    """
    Convert JSON sensor data to CSV format with error handling.

    Args:
        json_file_path: Path to input JSON file
        csv_file_path: Path to output CSV file
    """
    # Define CSV columns
    columns = ['time', 'acc_x', 'acc_y', 'acc_z', 'gyro_x', 'gyro_y', 'gyro_z', 'label']

    try:
        # Read the JSON file
        with open(json_file_path, 'r') as f:
            content = f.read()

        # Try to parse the JSON
        try:
            data = json.loads(content)
        except json.JSONDecodeError as e:
            print(f"JSON parsing error: {e}")
            print("Attempting to fix the JSON file...")

            # Try to fix common issues
            # 1. Add closing bracket if missing
            if not content.rstrip().endswith(']'):
                content = content.rstrip().rstrip(',') + ']'
                data = json.loads(content)
            else:
                raise

        # Ensure data is a list
        if not isinstance(data, list):
            print("Error: JSON root should be an array")
            return

        # Write to CSV
        with open(csv_file_path, 'w', newline='') as f:
            writer = csv.DictWriter(f, fieldnames=columns)
            writer.writeheader()

            # Write each record
            valid_records = 0
            for i, record in enumerate(data):
                try:
                    writer.writerow({
                        'time': record.get('time', ''),
                        'acc_x': record.get('acc_x', ''),
                        'acc_y': record.get('acc_y', ''),
                        'acc_z': record.get('acc_z', ''),
                        'gyro_x': record.get('gyro_x', ''),
                        'gyro_y': record.get('gyro_y', ''),
                        'gyro_z': record.get('gyro_z', ''),
                        'label': record.get('label', '')
                    })
                    valid_records += 1
                except Exception as e:
                    print(f"Error writing record {i}: {e}")

        print(f"✓ CSV file created successfully: {csv_file_path}")
        print(f"✓ Total records written: {valid_records}")

    except FileNotFoundError:
        print(f"Error: File '{json_file_path}' not found")
    except Exception as e:
        print(f"Error: {e}")

# Usage
if __name__ == "__main__":
    input_file = "/content/merged_van.json"  # Your JSON file path in Colab
    output_file = "/content/sensor_van_data.csv"   # Output CSV file

    json_to_csv(input_file, output_file)
# Out:
# ✓ CSV file created successfully: /content/sensor_van_data.csv
# ✓ Total records written: 185588

# %%
import json
import csv
import re

def json_to_csv_robust(json_file_path, csv_file_path):
    """
    Convert incomplete/corrupted JSON sensor data to CSV.
    Extracts all valid records before corruption point.
    """
    columns = ['time', 'acc_x', 'acc_y', 'acc_z', 'gyro_x', 'gyro_y', 'gyro_z', 'label']

    print(f"Reading file: {json_file_path}")

    with open(json_file_path, 'r') as f:
        content = f.read()

    print(f"File size: {len(content)} characters")

    # Find all complete JSON objects using regex
    # Pattern matches: {"time":...} including nested content
    pattern = r'\{"time":[^}]*?"label":"[^"]+"\}'
    matches = re.findall(pattern, content)

    print(f"Found {len(matches)} complete records")

    # Write to CSV
    with open(csv_file_path, 'w', newline='') as f:
        writer = csv.DictWriter(f, fieldnames=columns)
        writer.writeheader()

        valid_records = 0
        for i, match in enumerate(matches):
            try:
                record = json.loads(match)
                writer.writerow({
                    'time': record.get('time', ''),
                    'acc_x': record.get('acc_x', ''),
                    'acc_y': record.get('acc_y', ''),
                    'acc_z': record.get('acc_z', ''),
                    'gyro_x': record.get('gyro_x', ''),
                    'gyro_y': record.get('gyro_y', ''),
                    'gyro_z': record.get('gyro_z', ''),
                    'label': record.get('label', '')
                })
                valid_records += 1
            except json.JSONDecodeError as e:
                print(f"Skipping record {i}: {e}")
                continue

    print(f"\n✓ CSV file created: {csv_file_path}")
    print(f"✓ Valid records written: {valid_records}")
    return valid_records

# Usage for merged_bus.json
input_file = "/content/merged_van.json"
output_file = "/content/sensor_van_data.csv"

json_to_csv_robust(input_file, output_file)
# Out:
# Reading file: /content/merged_van.json
# File size: 41950419 characters
# Found 185588 complete records
#
# ✓ CSV file created: /content/sensor_van_data.csv
# ✓ Valid records written: 185588
# 185588

# %%
import pandas as pd
import glob

def merge_csv_files(csv_files, output_file):
    """
    Merge multiple CSV files into a single file.

    Args:
        csv_files: List of CSV file paths
        output_file: Output merged CSV file path
    """
    print("Merging CSV files...\n")

    all_data = []

    for csv_file in csv_files:
        try:
            df = pd.read_csv(csv_file)
            print(f"✓ Loaded {csv_file}: {len(df)} records")
            all_data.append(df)
        except Exception as e:
            print(f"✗ Error loading {csv_file}: {e}")

    # Combine all dataframes
    merged_df = pd.concat(all_data, ignore_index=True)

    # Save to CSV
    merged_df.to_csv(output_file, index=False)

    print(f"\n{'='*50}")
    print(f"✓ Merged CSV created: {output_file}")
    print(f"✓ Total records: {len(merged_df)}")
    print(f"✓ Columns: {list(merged_df.columns)}")

    # Show label distribution
    print(f"\n📊 Label distribution:")
    print(merged_df['label'].value_counts())
    print(f"{'='*50}")

# Method 1: Specify files manually
csv_files = [
    "/content/sensor_auto_data.csv",
    "/content/sensor_bus_data.csv",
    "/content/sensor_toto_data.csv",
    "/content/sensor_bike_data.csv",
    "/content/sensor_cycle_data.csv",
    "/content/sensor_train_data.csv",
    "/content/sensor_van_data.csv",
]

merge_csv_files(csv_files, "/content/sensor_data_merged.csv")
# Out:
# Merging CSV files...
#
# ✓ Loaded /content/sensor_auto_data.csv: 214357 records
# ✓ Loaded /content/sensor_bus_data.csv: 465265 records
# ✓ Loaded /content/sensor_toto_data.csv: 75948 records
# ✓ Loaded /content/sensor_bike_data.csv: 53360 records
# ✓ Loaded /content/sensor_cycle_data.csv: 105007 records
# ✓ Loaded /content/sensor_train_data.csv: 2964963 records
# ✓ Loaded /content/sensor_van_data.csv: 185588 records
#
# ...
# ✓ Merged CSV created: /content/sensor_data_merged.csv
# ✓ Total records: 4064488
# ✓ Columns: ['time', 'acc_x', 'acc_y', 'acc_z', 'gyro_x', 'gyro_y', 'gyro_z', 'label']
#
# 📊 Label distribution:
# label
# train    2964963
# bus       465265
# auto      214357
# van       185588
# cycle     105007
# toto       75948
# bike       53360
# Name: count, dtype: int64
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

def split_dataset(input_csv, train_ratio=0.7, val_ratio=0.15, test_ratio=0.15, random_state=42):
    """
    Split dataset into train, validation, and test sets.

    Args:
        input_csv: Path to merged CSV file
        train_ratio: Proportion for training (default: 0.7 = 70%)
        val_ratio: Proportion for validation (default: 0.15 = 15%)
        test_ratio: Proportion for testing (default: 0.15 = 15%)
        random_state: Random seed for reproducibility
    """

    # Verify ratios sum to 1
    assert abs(train_ratio + val_ratio + test_ratio - 1.0) < 0.001, "Ratios must sum to 1.0"

    # Load the data
    print(f"Loading data from: {input_csv}")
    df = pd.read_csv(input_csv)

    print(f"Total records: {len(df)}")
    print(f"\nLabel distribution in full dataset:")
    print(df['label'].value_counts())
    print(f"\n{'='*50}")

    # First split: separate train from (val + test)
    train_df, temp_df = train_test_split(
        df,
        test_size=(1 - train_ratio),
        random_state=random_state,
        stratify=df['label']  # Maintain label distribution
    )

    # Second split: separate val from test
    # Calculate the proportion of val in the temp set
    val_ratio_adjusted = val_ratio / (val_ratio + test_ratio)

    val_df, test_df = train_test_split(
        temp_df,
        test_size=(1 - val_ratio_adjusted),
        random_state=random_state,
        stratify=temp_df['label']
    )

    # Save the splits
    train_file = input_csv.replace('.csv', '_train.csv')
    val_file = input_csv.replace('.csv', '_val.csv')
    test_file = input_csv.replace('.csv', '_test.csv')

    train_df.to_csv(train_file, index=False)
    val_df.to_csv(val_file, index=False)
    test_df.to_csv(test_file, index=False)

    # Print statistics
    print(f"✓ Training set: {len(train_df)} records ({train_ratio*100:.1f}%)")
    print(f"  Saved to: {train_file}")
    print(f"  Label distribution:")
    print(f"  {train_df['label'].value_counts().to_dict()}\n")

    print(f"✓ Validation set: {len(val_df)} records ({val_ratio*100:.1f}%)")
    print(f"  Saved to: {val_file}")
    print(f"  Label distribution:")
    print(f"  {val_df['label'].value_counts().to_dict()}\n")

    print(f"✓ Test set: {len(test_df)} records ({test_ratio*100:.1f}%)")
    print(f"  Saved to: {test_file}")
    print(f"  Label distribution:")
    print(f"  {test_df['label'].value_counts().to_dict()}\n")

    print(f"{'='*50}")
    print(f"✓ Dataset split completed!")

    return train_df, val_df, test_df

# Usage - Standard 70/15/15 split
input_file = "/content/sensor_data_merged.csv"
train_df, val_df, test_df = split_dataset(input_file)
# Out:
# Loading data from: /content/sensor_data_merged.csv
# Total records: 4064488
#
# Label distribution in full dataset:
# label
# train    2964963
# bus       465265
# auto      214357
# van       185588
# cycle     105007
# toto       75948
# bike       53360
# Name: count, dtype: int64
#
# ...
# ✓ Training set: 2845141 records (70.0%)
#   Saved to: /content/sensor_data_merged_train.csv
#   Label distribution:
#   {'train': 2075474, 'bus': 325685, 'auto': 150050, 'van': 129911, 'cycle': 73505, 'toto': 53164, 'bike': 37352}
#
# ✓ Validation set: 609673 records (15.0%)
#   Saved to: /content/sensor_data_merged_val.csv
#   Label distribution:
#   {'train': 444744, 'bus': 69790, 'auto': 32153, 'van': 27839, 'cycle': 15751, 'toto': 11392, 'bike': 8004}
#
# ✓ Test set: 609674 records (15.0%)
#   Saved to: /content/sensor_data_merged_test.csv
#   Label distribution:
#   {'train': 444745, 'bus': 69790, 'auto': 32154, 'van': 27838, 'cycle': 15751, 'toto': 11392, 'bike': 8004}
#
# ...

# %%
# Install required packages
# !pip install torch torchvision torchaudio
# !pip install scikit-learn pandas numpy matplotlib seaborn

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import os

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# ...
# PyTorch version: 2.10.0+cu128
# CUDA available: True
# Using device: cuda

# %%
class IMUDataset(Dataset):
    """Dataset class for IMU sensor data."""

    def __init__(self, csv_file, window_size=100, stride=50, label_encoder=None):
        """
        Args:
            csv_file: Path to CSV file
            window_size: Number of timesteps in each window
            stride: Stride for sliding window
            label_encoder: LabelEncoder for labels (fit on train, use on val/test)
        """
        self.data = pd.read_csv(csv_file)
        self.window_size = window_size
        self.stride = stride

        # Shuffle the data to ensure windows get a mix of labels, if possible
        self.data = self.data.sample(frac=1, random_state=42).reset_index(drop=True)

        # Feature columns (sensor data)
        self.feature_cols = ['acc_x', 'acc_y', 'acc_z', 'gyro_x', 'gyro_y', 'gyro_z']

        # Encode labels
        if label_encoder is None:
            self.label_encoder = LabelEncoder()
            self.labels_encoded = self.label_encoder.fit_transform(self.data['label'])
        else:
            self.label_encoder = label_encoder
            self.labels_encoded = self.label_encoder.transform(self.data['label'])

        # Create windows
        self.windows, self.window_labels = self._create_windows()

        print(f"Dataset loaded: {len(self.windows)} windows")
        print(f"Classes: {self.label_encoder.classes_}")
        print(f"Window size: {window_size}, Stride: {stride}")

    def _create_windows(self):
        """Create sliding windows from the data."""
        windows = []
        labels = []

        # Get sensor data as numpy array
        sensor_data = self.data[self.feature_cols].values

        # Create sliding windows
        for i in range(0, len(sensor_data) - self.window_size + 1, self.stride):
            window = sensor_data[i:i + self.window_size]
            # Use the most common label in the window
            window_labels_slice = self.labels_encoded[i:i + self.window_size]
            label = np.bincount(window_labels_slice).argmax()

            windows.append(window)
            labels.append(label)

        return np.array(windows, dtype=np.float32), np.array(labels, dtype=np.int64)

    def __len__(self):
        return len(self.windows)

    def __getitem__(self, idx):
        """
        Returns:
            window: (window_size, num_features) tensor
            label: scalar label
        """
        return torch.FloatTensor(self.windows[idx]), torch.LongTensor([self.window_labels[idx]])[0]

# %%
class PositionalEncoding(nn.Module):
    """Positional encoding for transformer."""

    def __init__(self, d_model, max_len=5000):
        super(PositionalEncoding, self).__init__()

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-np.log(10000.0) / d_model))

        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)

        self.register_buffer('pe', pe)

    def forward(self, x):
        """
        Args:
            x: (batch_size, seq_len, d_model)
        """
        return x + self.pe[:, :x.size(1), :]


class IMUTransformer(nn.Module):
    """Transformer model for IMU-based activity recognition."""

    def __init__(self, input_dim=6, d_model=128, nhead=8, num_layers=4,
                 dim_feedforward=512, num_classes=7, dropout=0.1):
        """
        Args:
            input_dim: Number of input features (6 for IMU: 3 acc + 3 gyro)
            d_model: Dimension of the model
            nhead: Number of attention heads
            num_layers: Number of transformer layers
            dim_feedforward: Dimension of feedforward network
            num_classes: Number of output classes
            dropout: Dropout rate
        """
        super(IMUTransformer, self).__init__()

        # Input projection
        self.input_projection = nn.Linear(input_dim, d_model)

        # Positional encoding
        self.pos_encoder = PositionalEncoding(d_model)

        # Transformer encoder
        encoder_layers = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead,
            dim_feedforward=dim_feedforward,
            dropout=dropout,
            batch_first=True
        )
        self.transformer_encoder = nn.TransformerEncoder(encoder_layers, num_layers=num_layers)

        # Classification head
        self.dropout = nn.Dropout(dropout)
        self.fc1 = nn.Linear(d_model, 256)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(256, num_classes)

    def forward(self, x):
        """
        Args:
            x: (batch_size, seq_len, input_dim)
        Returns:
            output: (batch_size, num_classes)
        """
        # Project input to d_model dimensions
        x = self.input_projection(x)  # (batch, seq_len, d_model)

        # Add positional encoding
        x = self.pos_encoder(x)

        # Pass through transformer
        x = self.transformer_encoder(x)  # (batch, seq_len, d_model)

        # Global average pooling
        x = torch.mean(x, dim=1)  # (batch, d_model)

        # Classification
        x = self.dropout(x)
        x = self.fc1(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.fc2(x)

        return x

# %%
def train_epoch(model, dataloader, criterion, optimizer, device):
    """Train for one epoch."""
    model.train()
    running_loss = 0.0
    all_preds = []
    all_labels = []

    for inputs, labels in tqdm(dataloader, desc="Training"):
        inputs, labels = inputs.to(device), labels.to(device)

        # Zero gradients
        optimizer.zero_grad()

        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs, labels)

        # Backward pass
        loss.backward()
        optimizer.step()

        # Statistics
        running_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

    epoch_loss = running_loss / len(dataloader)
    epoch_acc = accuracy_score(all_labels, all_preds)

    return epoch_loss, epoch_acc


def evaluate(model, dataloader, criterion, device):
    """Evaluate the model."""
    model.eval()
    running_loss = 0.0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for inputs, labels in tqdm(dataloader, desc="Evaluating"):
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = model(inputs)
            loss = criterion(outputs, labels)

            running_loss += loss.item()
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    epoch_loss = running_loss / len(dataloader)
    epoch_acc = accuracy_score(all_labels, all_preds)

    return epoch_loss, epoch_acc, all_preds, all_labels


def plot_confusion_matrix(y_true, y_pred, classes, save_path='confusion_matrix.png'):
    """Plot confusion matrix."""
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=classes, yticklabels=classes)
    plt.title('Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.tight_layout()
    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    plt.show()
    print(f"Confusion matrix saved to {save_path}")


def plot_training_history(train_losses, val_losses, train_accs, val_accs, save_path='training_history.png'):
    """Plot training history."""
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

    # Loss plot
    ax1.plot(train_losses, label='Train Loss', marker='o')
    ax1.plot(val_losses, label='Val Loss', marker='s')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Loss')
    ax1.set_title('Training and Validation Loss')
    ax1.legend()
    ax1.grid(True)

    # Accuracy plot
    ax2.plot(train_accs, label='Train Acc', marker='o')
    ax2.plot(val_accs, label='Val Acc', marker='s')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Accuracy')
    ax2.set_title('Training and Validation Accuracy')
    ax2.legend()
    ax2.grid(True)

    plt.tight_layout()
    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    plt.show()
    print(f"Training history saved to {save_path}")

# %%
def main():
    """Main training pipeline."""

    # Hyperparameters
    WINDOW_SIZE = 100  # Number of timesteps per window
    STRIDE = 50        # Sliding window stride
    BATCH_SIZE = 64
    NUM_EPOCHS = 3
    LEARNING_RATE = 0.001

    # Model hyperparameters
    D_MODEL = 128
    NHEAD = 8
    NUM_LAYERS = 4
    DIM_FEEDFORWARD = 512
    DROPOUT = 0.1

    # File paths
    TRAIN_CSV = "/content/sensor_data_merged_train.csv"
    VAL_CSV = "/content/sensor_data_merged_val.csv"
    TEST_CSV = "/content/sensor_data_merged_test.csv"

    print("="*60)
    print("TRAVEL MEDIUM DETECTION WITH TRANSFORMER")
    print("="*60)

    # Create datasets
    print("\n📊 Loading datasets...")
    train_dataset = IMUDataset(TRAIN_CSV, window_size=WINDOW_SIZE, stride=STRIDE)
    val_dataset = IMUDataset(VAL_CSV, window_size=WINDOW_SIZE, stride=STRIDE,
                              label_encoder=train_dataset.label_encoder)
    test_dataset = IMUDataset(TEST_CSV, window_size=WINDOW_SIZE, stride=STRIDE,
                               label_encoder=train_dataset.label_encoder)

    # Create dataloaders
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=2)
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2)
    test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2)

    num_classes = len(train_dataset.label_encoder.classes_)
    print(f"\n✓ Number of classes: {num_classes}")
    print(f"✓ Classes: {train_dataset.label_encoder.classes_}")

    # Create model
    print("\n🤖 Creating model...")
    model = IMUTransformer(
        input_dim=6,
        d_model=D_MODEL,
        nhead=NHEAD,
        num_layers=NUM_LAYERS,
        dim_feedforward=DIM_FEEDFORWARD,
        num_classes=num_classes,
        dropout=DROPOUT
    ).to(device)

    # Count parameters
    total_params = sum(p.numel() for p in model.parameters())
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f"✓ Total parameters: {total_params:,}")
    print(f"✓ Trainable parameters: {trainable_params:,}")

    # Loss and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5)

    # Training loop
    print("\n🚀 Starting training...")
    print("="*60)

    best_val_acc = 0.0
    train_losses, val_losses = [], []
    train_accs, val_accs = [], []

    for epoch in range(NUM_EPOCHS):
        print(f"\nEpoch [{epoch+1}/{NUM_EPOCHS}]")

        # Train
        train_loss, train_acc = train_epoch(model, train_loader, criterion, optimizer, device)

        # Validate
        val_loss, val_acc, _, _ = evaluate(model, val_loader, criterion, device)

        # Learning rate scheduling
        current_lr = optimizer.param_groups[0]['lr']
        scheduler.step(val_loss)
        new_lr = optimizer.param_groups[0]['lr']

        # Print LR change if it happened
        if current_lr != new_lr:
            print(f"📉 Learning rate reduced: {current_lr:.6f} -> {new_lr:.6f}")

        # Save best model - FIXED: Save only model weights and metadata separately
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            # Save model weights
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'val_acc': val_acc,
            }, '/content/best_model.pth')

            # Save label encoder separately using pickle
            import pickle
            with open('/content/label_encoder.pkl', 'wb') as f:
                pickle.dump(train_dataset.label_encoder, f)

            print(f"✓ Best model saved! (Val Acc: {val_acc:.4f})")

        # Record history
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        train_accs.append(train_acc)
        val_accs.append(val_acc)

        # Print statistics
        print(f"Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.4f}")
        print(f"Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.4f}")
        print(f"Best Val Acc: {best_val_acc:.4f}")
        print(f"Current LR: {optimizer.param_groups[0]['lr']:.6f}")

    print("\n" + "="*60)
    print("Training completed!")
    print("="*60)

    # Plot training history
    plot_training_history(train_losses, val_losses, train_accs, val_accs,
                          '/content/training_history.png')

    # Load best model for testing - FIXED: Load with weights_only=False
    print("\n📊 Evaluating on test set...")
    checkpoint = torch.load('/content/best_model.pth', weights_only=True)
    model.load_state_dict(checkpoint['model_state_dict'])

    test_loss, test_acc, test_preds, test_labels = evaluate(model, test_loader, criterion, device)

    print(f"\n{'='*60}")
    print(f"TEST RESULTS")
    print(f"{'='*60}")
    print(f"Test Loss: {test_loss:.4f}")
    print(f"Test Accuracy: {test_acc:.4f}")

    # Classification report
    print("\n📋 Classification Report:")
    print(classification_report(test_labels, test_preds,
                                labels=range(num_classes),
                                target_names=train_dataset.label_encoder.classes_))

    # Confusion matrix
    plot_confusion_matrix(test_labels, test_preds,
                          train_dataset.label_encoder.classes_,
                          '/content/confusion_matrix.png')

    return model, train_dataset.label_encoder

# Run training
model, label_encoder = main()
# Out:
# ...
# TRAVEL MEDIUM DETECTION WITH TRANSFORMER
# ...
#
# 📊 Loading datasets...
# Dataset loaded: 56901 windows
# Classes: ['auto' 'bike' 'bus' 'cycle' 'toto' 'train' 'van']
# Window size: 100, Stride: 50
# Dataset loaded: 12192 windows
# Classes: ['auto' 'bike' 'bus' 'cycle' 'toto' 'train' 'van']
# Window size: 100, Stride: 50
# Dataset loaded: 12192 windows
# Classes: ['auto' 'bike' 'bus' 'cycle' 'toto' 'train' 'van']
# Window size: 100, Stride: 50
#
# ✓ Number of classes: 7
# ✓ Classes: ['auto' 'bike' 'bus' 'cycle' 'toto' 'train' 'van']
#
# 🤖 Creating model...
# ✓ Total parameters: 828,807
# ✓ Trainable parameters: 828,807
#
# 🚀 Starting training...
# ...
#
# Epoch [1/3]
# ...
# Evaluating: 100%|██████████| 191/191 [00:02<00:00, 78.45it/s]
# ✓ Best model saved! (Val Acc: 1.0000)
# Train Loss: 0.0042 | Train Acc: 0.9989
# Val Loss: 0.0000 | Val Acc: 1.0000
# Best Val Acc: 1.0000
# Current LR: 0.001000
#
# Epoch [2/3]
# ...
# Evaluating: 100%|██████████| 191/191 [00:02<00:00, 79.63it/s]
# ...

# %%
def predict_travel_medium(model, label_encoder, sensor_data, window_size=100, device='cpu'):
    """
    Predict travel medium from sensor data.

    Args:
        model: Trained model
        label_encoder: LabelEncoder for classes
        sensor_data: numpy array of shape (n_timesteps, 6) with columns [acc_x, acc_y, acc_z, gyro_x, gyro_y, gyro_z]
        window_size: Window size used during training
        device: Device to run inference on

    Returns:
        predicted_class: Predicted travel medium
        confidence: Prediction confidence
    """
    model.eval()

    # If data is shorter than window size, pad it
    if len(sensor_data) < window_size:
        padding = np.zeros((window_size - len(sensor_data), 6))
        sensor_data = np.vstack([sensor_data, padding])

    # Take the last window_size timesteps
    window = sensor_data[-window_size:]

    # Convert to tensor
    window_tensor = torch.FloatTensor(window).unsqueeze(0).to(device)  # (1, window_size, 6)

    with torch.no_grad():
        output = model(window_tensor)
        probabilities = torch.softmax(output, dim=1)
        confidence, predicted = torch.max(probabilities, 1)

    predicted_class = label_encoder.inverse_transform([predicted.cpu().item()])[0]
    confidence = confidence.cpu().item()

    return predicted_class, confidence


# Example usage
print("\n🔮 Example Prediction:")
print("="*60)

# Load some test data
test_data = pd.read_csv("/content/sensor_data_merged_test.csv")
sample_data = test_data[['acc_x', 'acc_y', 'acc_z', 'gyro_x', 'gyro_y', 'gyro_z']].values[:100]
actual_label = test_data['label'].values[0]

predicted_medium, confidence = predict_travel_medium(model, label_encoder, sample_data, device=device)

print(f"Actual: {actual_label}")
print(f"Predicted: {predicted_medium}")
print(f"Confidence: {confidence:.4f}")
print("="*60)
# Out:
# 🔮 Example Prediction:
# ...
# Actual: bus
# Predicted: train
# Confidence: 1.0000
# ...

# %%
# Save the complete model
torch.save({
    'model_state_dict': model.state_dict(),
    'label_encoder': label_encoder,
    'model_config': {
        'input_dim': 6,
        'd_model': 128,
        'nhead': 8,
        'num_layers': 4,
        'dim_feedforward': 512,
        'num_classes': len(label_encoder.classes_),
        'dropout': 0.1
    },
    'window_size': 100
}, '/content/travel_medium_model_complete.pth')

print("✓ Complete model saved to: /content/travel_medium_model_complete.pth")

# Download files from Colab
from google.colab import files
files.download('/content/best_model.pth')
files.download('/content/travel_medium_model_complete.pth')
files.download('/content/training_history.png')
files.download('/content/confusion_matrix.png')
# Out:
# ✓ Complete model saved to: /content/travel_medium_model_complete.pth

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

def main_balanced():
    """Main training pipeline with class balancing."""

    # Hyperparameters
    WINDOW_SIZE = 100
    STRIDE = 50
    BATCH_SIZE = 64
    NUM_EPOCHS = 3
    LEARNING_RATE = 0.001

    # Model hyperparameters
    D_MODEL = 128
    NHEAD = 8
    NUM_LAYERS = 4
    DIM_FEEDFORWARD = 512
    DROPOUT = 0.2  # Increased dropout

    # File paths
    TRAIN_CSV = "/content/sensor_data_merged_train.csv"
    VAL_CSV = "/content/sensor_data_merged_val.csv"
    TEST_CSV = "/content/sensor_data_merged_test.csv"

    print("="*60)
    print("BALANCED TRAVEL MEDIUM DETECTION")
    print("="*60)

    # Create datasets
    print("\n📊 Loading datasets...")
    train_dataset = IMUDataset(TRAIN_CSV, window_size=WINDOW_SIZE, stride=STRIDE)
    val_dataset = IMUDataset(VAL_CSV, window_size=WINDOW_SIZE, stride=STRIDE,
                              label_encoder=train_dataset.label_encoder)
    test_dataset = IMUDataset(TEST_CSV, window_size=WINDOW_SIZE, stride=STRIDE,
                               label_encoder=train_dataset.label_encoder)

    num_classes = len(train_dataset.label_encoder.classes_)
    print(f"\n✓ Number of classes: {num_classes}")
    print(f"✓ Classes: {train_dataset.label_encoder.classes_}")

    # Calculate class distribution
    print("\n📊 Training set class distribution:")
    unique, counts = np.unique(train_dataset.window_labels, return_counts=True)
    for idx, count in zip(unique, counts):
        class_name = train_dataset.label_encoder.inverse_transform([idx])[0]
        print(f"  {class_name}: {count} ({count/len(train_dataset)*100:.2f}%)वरुन)")

    # ============================================
    # STRATEGY 1: WEIGHTED RANDOM SAMPLING
    # ============================================
    print("\n⚖️ Creating balanced sampler...")
    class_counts = np.bincount(train_dataset.window_labels)
    # Handle cases where a class might not be present in window_labels (i.e., its count is 0)
    # This also addresses the RuntimeWarning from division by zero.
    class_weights = np.zeros(num_classes)
    for i in range(len(class_counts)):
        if class_counts[i] > 0:
            class_weights[i] = 1.0 / class_counts[i]
        else:
            class_weights[i] = 0 # Or a very small number, but 0 means that class will not be sampled if not present

    sample_weights = class_weights[train_dataset.window_labels]

    sampler = WeightedRandomSampler(
        weights=sample_weights,
        num_samples=len(sample_weights),
        replacement=True
    )

    # Create dataloaders with sampler
    train_loader = DataLoader(
        train_dataset,
        batch_size=BATCH_SIZE,
        sampler=sampler,  # Use weighted sampler instead of shuffle
        num_workers=2
    )
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2)
    test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2)

    # ============================================
    # STRATEGY 2: CLASS WEIGHTS IN LOSS FUNCTION
    # ============================================
    print("\n⚖️ Computing class weights for loss...")

    # Find unique labels actually present in the windowed training data
    unique_labels_in_windows = np.unique(train_dataset.window_labels)

    # Compute balanced weights only for the classes present in the windowed data
    class_weights_computed = compute_class_weight(
        class_weight='balanced',
        classes=unique_labels_in_windows, # Pass only the classes actually found in y
        y=train_dataset.window_labels
    )

    # Create a full weight tensor of size num_classes, initialized to zeros
    class_weights_full_tensor = torch.zeros(num_classes, dtype=torch.float32)

    # Map the computed weights back to their original class indices
    for i, class_idx in enumerate(unique_labels_in_windows):
        class_weights_full_tensor[class_idx] = class_weights_computed[i]

    # Move to device
    class_weights_tensor = class_weights_full_tensor.to(device)

    print("Class weights for loss:")
    for idx, weight in enumerate(class_weights_tensor.cpu().numpy()): # Print from the full tensor
        class_name = train_dataset.label_encoder.inverse_transform([idx])[0]
        print(f"  {class_name}: {weight:.4f}")

    # Create model
    print("\n🤖 Creating model...")
    model = IMUTransformer(
        input_dim=6,
        d_model=D_MODEL,
        nhead=NHEAD,
        num_layers=NUM_LAYERS,
        dim_feedforward=DIM_FEEDFORWARD,
        num_classes=num_classes,
        dropout=DROPOUT
    ).to(device)

    total_params = sum(p.numel() for p in model.parameters())
    print(f"✓ Total parameters: {total_params:,}")

    # Weighted loss function
    criterion = nn.CrossEntropyLoss(weight=class_weights_tensor)
    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE, weight_decay=1e-4)  # Added weight decay
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5)

    # Training loop
    print("\n🚀 Starting training...")
    print("="*60)

    best_val_acc = 0.0
    best_val_f1 = 0.0
    train_losses, val_losses = [], []
    train_accs, val_accs = [], []
    patience_counter = 0
    early_stop_patience = 15

    for epoch in range(NUM_EPOCHS):
        print(f"\nEpoch [{epoch+1}/{NUM_EPOCHS}]")

        # Train
        train_loss, train_acc = train_epoch(model, train_loader, criterion, optimizer, device)

        # Validate
        val_loss, val_acc, val_preds, val_labels = evaluate(model, val_loader, criterion, device)

        # Calculate F1 score for better metric with imbalanced data
        from sklearn.metrics import f1_score
        val_f1 = f1_score(val_labels, val_preds, average='macro')

        # Learning rate scheduling
        current_lr = optimizer.param_groups[0]['lr']
        scheduler.step(val_loss)
        new_lr = optimizer.param_groups[0]['lr']

        if current_lr != new_lr:
            print(f"📉 Learning rate reduced: {current_lr:.6f} -> {new_lr:.6f}")

        # Save best model based on F1 score (better for imbalanced data)
        if val_f1 > best_val_f1:
            best_val_f1 = val_f1
            best_val_acc = val_acc
            patience_counter = 0

            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'val_acc': val_acc,
                'val_f1': val_f1,
            }, '/content/best_model_balanced.pth')

            import pickle
            with open('/content/label_encoder.pkl', 'wb') as f:
                pickle.dump(train_dataset.label_encoder, f)

            print(f"✓ Best model saved! (Val F1: {val_f1:.4f}, Val Acc: {val_acc:.4f})")
        else:
            patience_counter += 1

        # Record history
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        train_accs.append(train_acc)
        val_accs.append(val_acc)

        # Print statistics
        print(f"Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.4f}")
        print(f"Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.4f} | Val F1: {val_f1:.4f}")
        print(f"Best Val F1: {best_val_f1:.4f} | Best Val Acc: {best_val_acc:.4f}")
        print(f"Current LR: {optimizer.param_groups[0]['lr']:.6f}")

        # Early stopping
        if patience_counter >= early_stop_patience:
            print(f"\n⚠️ Early stopping triggered after {epoch+1} epochs")
            break

    print("\n" + "="*60)
    print("Training completed!")
    print("="*60)

    # Plot training history
    plot_training_history(train_losses, val_losses, train_accs, val_accs,
                          '/content/training_history_balanced.png')

    # Load best model for testing
    print("\n📊 Evaluating on test set...")
    checkpoint = torch.load('/content/best_model_balanced.pth', weights_only=True)
    model.load_state_dict(checkpoint['model_state_dict'])

    test_loss, test_acc, test_preds, test_labels = evaluate(model, test_loader, criterion, device)

    print(f"\n{'='*60}")
    print(f"TEST RESULTS")
    print(f"{'='*60}")
    print(f"Test Loss: {test_loss:.4f}")
    print(f"Test Accuracy: {test_acc:.4f}")

    # Calculate per-class metrics
    from sklearn.metrics import f1_score
    test_f1_macro = f1_score(test_labels, test_preds, average='macro')
    test_f1_weighted = f1_score(test_labels, test_preds, average='weighted')

    print(f"Test F1 (Macro): {test_f1_macro:.4f}")
    print(f"Test F1 (Weighted): {test_f1_weighted:.4f}")

    # Classification report
    print("\n📋 Classification Report:")
    print(classification_report(test_labels, test_preds,
                                target_names=train_dataset.label_encoder.classes_,
                                zero_division=0))

    # Confusion matrix
    plot_confusion_matrix(test_labels, test_preds,
                          train_dataset.label_encoder.classes_,
                          '/content/confusion_matrix_balanced.png')

    # Per-class accuracy
    print("\n📊 Per-Class Accuracy:")
    cm = confusion_matrix(test_labels, test_preds)
    per_class_acc = cm.diagonal() / cm.sum(axis=1)
    for idx, acc in enumerate(per_class_acc):
        class_name = train_dataset.label_encoder.classes_[idx]
        print(f"  {class_name}: {acc:.4f}")

    return model, train_dataset.label_encoder

# Run training
model, label_encoder = main_balanced()
# Out:
# ...
# BALANCED TRAVEL MEDIUM DETECTION
# ...
#
# 📊 Loading datasets...
# Dataset loaded: 56901 windows
# Classes: ['auto' 'bike' 'bus' 'cycle' 'toto' 'train' 'van']
# Window size: 100, Stride: 50
# Dataset loaded: 12192 windows
# Classes: ['auto' 'bike' 'bus' 'cycle' 'toto' 'train' 'van']
# Window size: 100, Stride: 50
# Dataset loaded: 12192 windows
# Classes: ['auto' 'bike' 'bus' 'cycle' 'toto' 'train' 'van']
# Window size: 100, Stride: 50
#
# ✓ Number of classes: 7
# ✓ Classes: ['auto' 'bike' 'bus' 'cycle' 'toto' 'train' 'van']
#
# 📊 Training set class distribution:
#   train: 56901 (100.00%)वरुन)
#
# ⚖️ Creating balanced sampler...
#
# ⚖️ Computing class weights for loss...
# Class weights for loss:
#   auto: 0.0000
#   bike: 0.0000
#   bus: 0.0000
#   cycle: 0.0000
#   toto: 0.0000
#   train: 1.0000
#   van: 0.0000
#
# 🤖 Creating model...
# ✓ Total parameters: 828,807
#
# 🚀 Starting training...
# ...
#
# Epoch [1/3]
# ...
# Evaluating: 100%|██████████| 191/191 [00:02<00:00, 78.51it/s]
# ...
